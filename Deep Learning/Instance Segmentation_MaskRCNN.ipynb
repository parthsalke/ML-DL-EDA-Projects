# %%
#Install Libraries

# %%
# !pip install tensorflow==2.4.1 tensorflow-gpu==2.4.1 pixellib opencv-python
# Out:
# Collecting tensorflow==2.4.1
#   Downloading tensorflow-2.4.1-cp38-cp38-win_amd64.whl (370.7 MB)
# Collecting tensorflow-gpu==2.4.1
#   Downloading tensorflow_gpu-2.4.1-cp38-cp38-win_amd64.whl (370.7 MB)
# Collecting pixellib
#   Downloading pixellib-0.7.1-py3-none-any.whl (430 kB)
# Requirement already satisfied: opencv-python in c:\users\parth salke\anaconda3\lib\site-packages (4.5.5.64)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorflow==2.4.1) (3.19.4)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorflow==2.4.1) (1.1.0)
# Collecting wheel~=0.35
#   Using cached wheel-0.37.1-py2.py3-none-any.whl (35 kB)
# Collecting absl-py~=0.10
#   Using cached absl_py-0.15.0-py3-none-any.whl (132 kB)
# Requirement already satisfied: six~=1.15.0 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorflow==2.4.1) (1.15.0)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorflow==2.4.1) (1.6.3)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorflow==2.4.1) (3.7.4.2)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorflow==2.4.1) (3.3.0)
# Collecting wrapt~=1.12.1
#   Using cached wrapt-1.12.1.tar.gz (27 kB)
# Collecting gast==0.3.3
#   Downloading gast-0.3.3-py2.py3-none-any.whl (9.7 kB)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorflow==2.4.1) (1.1.2)
# Collecting tensorflow-estimator<2.5.0,>=2.4.0
#   Downloading tensorflow_estimator-2.4.0-py2.py3-none-any.whl (462 kB)
# Collecting flatbuffers~=1.12.0
#   Using cached flatbuffers-1.12-py2.py3-none-any.whl (15 kB)
# Collecting grpcio~=1.32.0
#   Downloading grpcio-1.32.0-cp38-cp38-win_amd64.whl (2.6 MB)
# Requirement already satisfied: h5py~=2.10.0 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorflow==2.4.1) (2.10.0)
# Requirement already satisfied: tensorboard~=2.4 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorflow==2.4.1) (2.8.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorflow==2.4.1) (0.2.0)
# Collecting numpy~=1.19.2
#   Downloading numpy-1.19.5-cp38-cp38-win_amd64.whl (13.3 MB)
# Collecting imantics
#   Downloading imantics-0.1.12.tar.gz (13 kB)
# Requirement already satisfied: tqdm in c:\users\parth salke\anaconda3\lib\site-packages (from pixellib) (4.47.0)
# Requirement already satisfied: scikit-image in c:\users\parth salke\anaconda3\lib\site-packages (from pixellib) (0.16.2)
# Collecting pydot
#   Downloading pydot-1.4.2-py2.py3-none-any.whl (21 kB)
# Collecting dataclasses
#   Downloading dataclasses-0.6-py3-none-any.whl (14 kB)
# Requirement already satisfied: pillow in c:\users\parth salke\anaconda3\lib\site-packages (from pixellib) (7.2.0)
# Collecting hydra-core
#   Downloading hydra_core-1.2.0-py3-none-any.whl (151 kB)
# Requirement already satisfied: Cython in c:\users\parth salke\anaconda3\lib\site-packages (from pixellib) (0.29.21)
# Collecting fvcore
#   Downloading fvcore-0.1.5.post20220512.tar.gz (50 kB)
# Collecting iopath
#   Downloading iopath-0.1.10.tar.gz (42 kB)
# Requirement already satisfied: future in c:\users\parth salke\anaconda3\lib\site-packages (from pixellib) (0.18.2)
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Collecting omegaconf
#   Downloading omegaconf-2.2.3-py3-none-any.whl (79 kB)
# Collecting labelme2coco
#   Downloading labelme2coco-0.2.1-py3-none-any.whl (18 kB)
# Collecting tabulate
#   Downloading tabulate-0.8.10-py3-none-any.whl (29 kB)
# Requirement already satisfied: matplotlib in c:\users\parth salke\anaconda3\lib\site-packages (from pixellib) (3.2.2)
# Collecting pyQt5
#   Downloading PyQt5-5.15.7-cp37-abi3-win_amd64.whl (6.8 MB)
# Requirement already satisfied: cloudpickle in c:\users\parth salke\anaconda3\lib\site-packages (from pixellib) (1.5.0)
# Collecting black
#   Downloading black-22.6.0-cp38-cp38-win_amd64.whl (1.2 MB)
# Collecting imgaug
#   Downloading imgaug-0.4.0-py2.py3-none-any.whl (948 kB)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.0.1)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (49.2.0.post20200714)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (0.4.6)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (2.6.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\parth salke\anaconda3\lib\site-packages (from tensorboard~=2.4->tensorflow==2.4.1) (2.24.0)
# Requirement already satisfied: lxml in c:\users\parth salke\anaconda3\lib\site-packages (from imantics->pixellib) (4.5.2)
# Collecting xmljson
#   Downloading xmljson-0.2.1-py2.py3-none-any.whl (10 kB)
# Requirement already satisfied: networkx>=2.0 in c:\users\parth salke\anaconda3\lib\site-packages (from scikit-image->pixellib) (2.4)
# Requirement already satisfied: PyWavelets>=0.4.0 in c:\users\parth salke\anaconda3\lib\site-packages (from scikit-image->pixellib) (1.1.1)
# Requirement already satisfied: imageio>=2.3.0 in c:\users\parth salke\anaconda3\lib\site-packages (from scikit-image->pixellib) (2.9.0)
# Requirement already satisfied: scipy>=0.19.0 in c:\users\parth salke\anaconda3\lib\site-packages (from scikit-image->pixellib) (1.5.0)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\parth salke\anaconda3\lib\site-packages (from pydot->pixellib) (2.4.7)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in c:\users\parth salke\anaconda3\lib\site-packages (from hydra-core->pixellib) (5.4.0)
# Requirement already satisfied: packaging in c:\users\parth salke\anaconda3\lib\site-packages (from hydra-core->pixellib) (20.4)
# Collecting antlr4-python3-runtime==4.9.*
#   Downloading antlr4-python3-runtime-4.9.3.tar.gz (117 kB)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\parth salke\anaconda3\lib\site-packages (from fvcore->pixellib) (5.3.1)
# Collecting portalocker
#   Downloading portalocker-2.5.1-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: jsonschema>=2.6.0 in c:\users\parth salke\anaconda3\lib\site-packages (from labelme2coco->pixellib) (3.2.0)
# Collecting sahi>=0.8.19
#   Downloading sahi-0.10.4-py3-none-any.whl (96 kB)
# Requirement already satisfied: cycler>=0.10 in c:\users\parth salke\anaconda3\lib\site-packages (from matplotlib->pixellib) (0.10.0)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\parth salke\anaconda3\lib\site-packages (from matplotlib->pixellib) (2.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\parth salke\anaconda3\lib\site-packages (from matplotlib->pixellib) (1.2.0)
# Collecting PyQt5-sip<13,>=12.11
#   Downloading PyQt5_sip-12.11.0-cp38-cp38-win_amd64.whl (78 kB)
# Collecting PyQt5-Qt5>=5.15.0
#   Downloading PyQt5_Qt5-5.15.2-py3-none-win_amd64.whl (50.1 MB)
# Collecting mypy-extensions>=0.4.3
#   Using cached mypy_extensions-0.4.3-py2.py3-none-any.whl (4.5 kB)
# Collecting click>=8.0.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting platformdirs>=2
#   Downloading platformdirs-2.5.2-py3-none-any.whl (14 kB)
# Collecting tomli>=1.1.0; python_full_version < "3.11.0a7"
#   Using cached tomli-2.0.1-py3-none-any.whl (12 kB)
# Collecting pathspec>=0.9.0
#   Using cached pathspec-0.9.0-py2.py3-none-any.whl (31 kB)
# Collecting Shapely
#   Downloading Shapely-1.8.4-cp38-cp38-win_amd64.whl (1.3 MB)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in c:\users\parth salke\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.4->tensorflow==2.4.1) (4.11.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\parth salke\anaconda3\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.1) (1.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\parth salke\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (4.8)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\parth salke\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\parth salke\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (5.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\parth salke\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\parth salke\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\parth salke\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\parth salke\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.4->tensorflow==2.4.1) (1.25.9)
# Requirement already satisfied: decorator>=4.3.0 in c:\users\parth salke\anaconda3\lib\site-packages (from networkx>=2.0->scikit-image->pixellib) (4.4.2)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in c:\users\parth salke\anaconda3\lib\site-packages (from importlib-resources; python_version < "3.9"->hydra-core->pixellib) (3.1.0)
# Requirement already satisfied: pywin32>=226; platform_system == "Windows" in c:\users\parth salke\anaconda3\lib\site-packages (from portalocker->iopath->pixellib) (227)
# Requirement already satisfied: attrs>=17.4.0 in c:\users\parth salke\anaconda3\lib\site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (19.3.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in c:\users\parth salke\anaconda3\lib\site-packages (from jsonschema>=2.6.0->labelme2coco->pixellib) (0.16.0)
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
# Collecting pybboxes==0.1.4; python_version >= "3.8"
#   Downloading pybboxes-0.1.4-py3-none-any.whl (23 kB)
# Collecting terminaltables
#   Downloading terminaltables-3.1.10-py2.py3-none-any.whl (15 kB)
# Requirement already satisfied: colorama; platform_system == "Windows" in c:\users\parth salke\anaconda3\lib\site-packages (from click>=8.0.0->black->pixellib) (0.4.3)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\parth salke\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.4->tensorflow==2.4.1) (3.2.0)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\parth salke\anaconda3\lib\site-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<3,>=1.6.3->tensorboard~=2.4->tensorflow==2.4.1) (0.4.8)
# Building wheels for collected packages: wrapt, imantics, fvcore, iopath, antlr4-python3-runtime, fire
#   Building wheel for wrapt (setup.py): started
#   Building wheel for wrapt (setup.py): finished with status 'done'
#   Created wheel for wrapt: filename=wrapt-1.12.1-cp38-cp38-win_amd64.whl size=33831 sha256=e3d07863791e08d78b9fe9ded75110a77641cf8b29d3bb648aeadadec357a715
#   Stored in directory: c:\users\parth salke\appdata\local\pip\cache\wheels\5f\fd\9e\b6cf5890494cb8ef0b5eaff72e5d55a70fb56316007d6dfe73
#   Building wheel for imantics (setup.py): started
#   Building wheel for imantics (setup.py): finished with status 'done'
#   Created wheel for imantics: filename=imantics-0.1.12-py3-none-any.whl size=16037 sha256=21d66394a04ffb83a9c33fe78b596b3967bf9c66bfd6037fe76c8941d8a9a299
#   Stored in directory: c:\users\parth salke\appdata\local\pip\cache\wheels\3d\a5\ec\e0fe6d18df133bf33ddc4a4148646677f45a24be2732b4ec86
#   Building wheel for fvcore (setup.py): started
#   Building wheel for fvcore (setup.py): finished with status 'done'
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20220512-py3-none-any.whl size=61293 sha256=1b4d14b81dc1b5bea073578588c48877de2dbe6b81ebb9a5eec7f33a70a582a0
#   Stored in directory: c:\users\parth salke\appdata\local\pip\cache\wheels\bc\f4\d9\8b3c3f254c28aa2daf5e2f5a8070b0a960278733fd2eb1f7a2
#   Building wheel for iopath (setup.py): started
#   Building wheel for iopath (setup.py): finished with status 'done'
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31547 sha256=b37ce6a7b5b48609f3ff973df67c8ba850832c00ed290d94b478a852ea8c6a10
#   Stored in directory: c:\users\parth salke\appdata\local\pip\cache\wheels\89\3e\24\0f349c0b2eeb6965903035f3b00dbb5c9bea437b4a2f18d82c
#   Building wheel for antlr4-python3-runtime (setup.py): started
#   Building wheel for antlr4-python3-runtime (setup.py): finished with status 'done'
#   Created wheel for antlr4-python3-runtime: filename=antlr4_python3_runtime-4.9.3-py3-none-any.whl size=144577 sha256=a32ae22e6cd3f1ea4742b6e14059005711ff2c76f1d54ce643a903bcfa048c9c
#   Stored in directory: c:\users\parth salke\appdata\local\pip\cache\wheels\b1\a3\c2\6df046c09459b73cc9bb6c4401b0be6c47048baf9a1617c485
#   Building wheel for fire (setup.py): started
#   Building wheel for fire (setup.py): finished with status 'done'
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115932 sha256=f8e235f282ceda437470beeb734a26827e0e8a0512e30167a3e1d798ff81a678
#   Stored in directory: c:\users\parth salke\appdata\local\pip\cache\wheels\1f\10\06\2a990ee4d73a8479fe2922445e8a876d38cfbfed052284c6a1
# Successfully built wrapt imantics fvcore iopath antlr4-python3-runtime fire
# Installing collected packages: wheel, absl-py, wrapt, gast, tensorflow-estimator, flatbuffers, grpcio, numpy, tensorflow, tensorflow-gpu, xmljson, imantics, pydot, dataclasses, antlr4-python3-runtime, omegaconf, hydra-core, yacs, tabulate, portalocker, iopath, fvcore, fire, pybboxes, click, Shapely, terminaltables, sahi, labelme2coco, PyQt5-sip, PyQt5-Qt5, pyQt5, mypy-extensions, platformdirs, tomli, pathspec, black, imgaug, pixellib
#   Attempting uninstall: wheel
#     Found existing installation: wheel 0.34.2
#     Uninstalling wheel-0.34.2:
#       Successfully uninstalled wheel-0.34.2
#   Attempting uninstall: absl-py
#     Found existing installation: absl-py 1.0.0
#     Uninstalling absl-py-1.0.0:
#       Successfully uninstalled absl-py-1.0.0
#   Attempting uninstall: wrapt
#     Found existing installation: wrapt 1.11.2
#     Uninstalling wrapt-1.11.2:
#       Successfully uninstalled wrapt-1.11.2
#   Attempting uninstall: gast
#     Found existing installation: gast 0.5.3
#     Uninstalling gast-0.5.3:
#       Successfully uninstalled gast-0.5.3
#   Attempting uninstall: flatbuffers
#     Found existing installation: flatbuffers 2.0
#     Uninstalling flatbuffers-2.0:
#       Successfully uninstalled flatbuffers-2.0
#   Attempting uninstall: grpcio
#     Found existing installation: grpcio 1.44.0
#     Uninstalling grpcio-1.44.0:
#       Successfully uninstalled grpcio-1.44.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.2
#     Uninstalling numpy-1.22.2:
#       Successfully uninstalled numpy-1.22.2
#   Attempting uninstall: tensorflow
#     Found existing installation: tensorflow 2.8.0
#     Uninstalling tensorflow-2.8.0:
#       Successfully uninstalled tensorflow-2.8.0
#   Attempting uninstall: tensorflow-gpu
#     Found existing installation: tensorflow-gpu 2.8.0
#     Uninstalling tensorflow-gpu-2.8.0:
#       Successfully uninstalled tensorflow-gpu-2.8.0
#   Attempting uninstall: click
#     Found existing installation: click 7.1.2
#     Uninstalling click-7.1.2:
#       Successfully uninstalled click-7.1.2
# Successfully installed PyQt5-Qt5-5.15.2 PyQt5-sip-12.11.0 Shapely-1.8.4 absl-py-0.15.0 antlr4-python3-runtime-4.9.3 black-22.6.0 click-8.1.3 dataclasses-0.6 fire-0.4.0 flatbuffers-1.12 fvcore-0.1.5.post20220512 gast-0.3.3 grpcio-1.32.0 hydra-core-1.2.0 imantics-0.1.12 imgaug-0.4.0 iopath-0.1.10 labelme2coco-0.2.1 mypy-extensions-0.4.3 numpy-1.19.5 omegaconf-2.2.3 pathspec-0.9.0 pixellib-0.7.1 platformdirs-2.5.2 portalocker-2.5.1 pyQt5-5.15.7 pybboxes-0.1.4 pydot-1.4.2 sahi-0.10.4 tabulate-0.8.10 tensorflow-2.4.1 tensorflow-estimator-2.4.0 tensorflow-gpu-2.4.1 terminaltables-3.1.10 tomli-2.0.1 wheel-0.37.1 wrapt-1.12.1 xmljson-0.2.1 yacs-0.1.8
# ERROR: spyder 4.1.4 requires pyqtwebengine<5.13; python_version >= "3", which is not installed.
# ERROR: face-recognition 1.4.0 requires dlib>=19.7, which is not installed.
# ERROR: face-recognition 1.4.0 requires face_recognition_models>=0.3.0, which is not installed.
# ERROR: spyder 4.1.4 has requirement pyqt5<5.13; python_version >= "3", but you'll have pyqt5 5.15.7 which is incompatible.
# ERROR: sahi 0.10.4 has requirement click==8.0.4, but you'll have click 8.1.3 which is incompatible.
# ERROR: sahi 0.10.4 has requirement pillow>=8.2.0, but you'll have pillow 7.2.0 which is incompatible.
# ERROR: sahi 0.10.4 has requirement tqdm>=4.48.2, but you'll have tqdm 4.47.0 which is incompatible.
# ERROR: black 22.6.0 has requirement typing-extensions>=3.10.0.0; python_version < "3.10", but you'll have typing-extensions 3.7.4.2 which is incompatible.

# %%
import pixellib
from pixellib.instance import instance_segmentation
import cv2

# %%
#Setup Model

# %%
segmentation_model = instance_segmentation()
segmentation_model.load_model('mask_rcnn_coco.h5')
# Out:
# WARNING:tensorflow:From C:\Users\Parth Salke\anaconda3\lib\site-packages\tensorflow\python\util\deprecation.py:605: calling map_fn_v2 (from tensorflow.python.ops.map_fn) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Use fn_output_signature instead

# %%
#Real time camera

# %%
cap = cv2.VideoCapture(0)
while cap.isOpened():
    ret, frame = cap.read()
    
    # Apply instance segmentation
    res = segmentation_model.segmentFrame(frame, show_bboxes=True)
    image = res[1]
    
    cv2.imshow('Instance Segmentation', image)
    
    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()
# Out:
# C:\Users\Parth Salke\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py:2325: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '
